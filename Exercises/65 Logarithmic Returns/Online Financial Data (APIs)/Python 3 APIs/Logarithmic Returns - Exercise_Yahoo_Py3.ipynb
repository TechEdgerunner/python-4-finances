# %% [markdown]
# ## Logarithmic Returns

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
MSFT = yf.download('MSFT', start='2000-1-1')
MSFT
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03   58.687500   59.312500   56.000000   58.281250   35.935863
# 2000-01-04   56.781250   58.562500   56.125000   56.312500   34.721947
# 2000-01-05   55.562500   58.187500   54.687500   56.906250   35.088032
# 2000-01-06   56.093750   56.937500   54.187500   55.000000   33.912670
# 2000-01-07   54.312500   56.125000   53.656250   55.718750   34.355858
# ...                ...         ...         ...         ...         ...
# 2024-08-09  404.029999  408.049988  402.260010  406.019989  405.289490
# 2024-08-12  407.059998  408.760010  404.239990  406.809998  406.078064
# 2024-08-13  409.589996  414.950012  409.570007  414.010010  413.265137
# 2024-08-14  414.799988  417.720001  412.450012  416.859985  416.109985
# 2024-08-15  419.799988  421.109985  417.660004  421.029999  421.029999
#
#               Volume
# Date
# ...

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT['log_return'] = np.log(MSFT['Adj Close'] / MSFT['Adj Close'].shift(1))
print(MSFT['log_return'])
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.034364
# 2000-01-05    0.010488
# 2000-01-06   -0.034071
# 2000-01-07    0.012984
#                 ...
# 2024-08-09    0.008235
# 2024-08-12    0.001944
# 2024-08-13    0.017544
# 2024-08-14    0.006860
# 2024-08-15    0.011754
# Name: log_return, Length: 6194, dtype: float64

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(16, 9))
plt.show()

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
daily_return = MSFT['log_return'].mean()

# %%
annual_return = MSFT['log_return'].mean() * 250

# %% [markdown]
# Print the result in a presentable form.

# %%
print('Annual return: ',round(annual_return*100, 2), '%')
print('Daily return: ',round(daily_return*100, 2), '%')
# Out:
# Annual return:  9.93 %
# Daily return:  0.04 %

# %% [markdown]
# ****

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)
