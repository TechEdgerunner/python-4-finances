# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
MSFT = yf.download('MSFT', start='2000-1-1')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033780
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
# 2000-01-07    0.013068
#                 ...
# 2024-08-12    0.001946
# 2024-08-13    0.017699
# 2024-08-14    0.006884
# 2024-08-15    0.011824
# 2024-08-16   -0.006175
# Name: simple_return, Length: 6195, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
MSFT['simple_return'].plot(figsize=(16, 8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Calculate the average daily return.

# %%
print (MSFT['simple_return'].mean())
# Out:
# 0.0005789222300544292

# %% [markdown]
# Estimate the average annual return.

# %%
print(MSFT['simple_return'].mean() * 250)
# Out:
# 0.1447305575136073

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print(round(MSFT['simple_return'].mean() * 250* 100, 2,),"%")
# Out:
# 14.47 %
